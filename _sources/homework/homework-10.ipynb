# %% [markdown]
# # Homework 10 — Physics-Informed Modeling and Posterior Characterization
#
# **Coverage:** Lectures 26–28<br>
# **Due:** Sunday, December 6, 2026, 11:59 p.m. ET
